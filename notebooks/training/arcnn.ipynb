# %%
# %cd aws-deepcomposer-samples-master/ar-cnn
# !mkdir checkpoints outputs
# !ls
# Out:
# /content/aws-deepcomposer-samples-master/ar-cnn
# augmentation.py		 inference_parameters.json  readme.md
# AutoRegressiveCNN.ipynb  inference.py		    requirements.txt
# checkpoints		 LICENSE.txt		    sample_inputs
# constants.py		 losses.py		    sample_outputs
# data_generator.py	 model.py		    utils
# images			 outputs

# %%
# !pip install -r requirements.txt
# Out:
# Collecting pypianoroll==0.5.3
#   Downloading https://files.pythonhosted.org/packages/17/93/cca689c3e7f217a4a1906f6b96e81c4d57d423ff6778dcc7af3bad11c638/pypianoroll-0.5.3.tar.gz
# Collecting music21==5.7.2
#   Downloading https://files.pythonhosted.org/packages/96/87/19a01af679090c880ed0036f0c221dd7bc3a97f4bddf74e24bc22d1e66cf/music21-5.7.2.tar.gz (18.5MB)
#      |████████████████████████████████| 18.5MB 78.3MB/s
# Collecting texttable==1.6.2
#   Downloading https://files.pythonhosted.org/packages/ec/b1/8a1c659ce288bf771d5b1c7cae318ada466f73bd0e16df8d86f27a2a3ee7/texttable-1.6.2-py2.py3-none-any.whl
# Requirement already satisfied: six<2.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from pypianoroll==0.5.3->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: numpy<2.0,>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from pypianoroll==0.5.3->-r requirements.txt (line 1)) (1.18.5)
# Requirement already satisfied: scipy<2.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from pypianoroll==0.5.3->-r requirements.txt (line 1)) (1.4.1)
# Collecting pretty_midi<1.0,>=0.2.8
#   Downloading https://files.pythonhosted.org/packages/bc/8e/63c6e39a7a64623a9cd6aec530070c70827f6f8f40deec938f323d7b1e15/pretty_midi-0.2.9.tar.gz (5.6MB)
#      |████████████████████████████████| 5.6MB 14.4MB/s
# Collecting mido>=1.1.16
#   Downloading https://files.pythonhosted.org/packages/20/0a/81beb587b1ae832ea6a1901dc7c6faa380e8dd154e0a862f0a9f3d2afab9/mido-1.2.9-py2.py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 9.3MB/s
# Building wheels for collected packages: pypianoroll, music21, pretty-midi
#   Building wheel for pypianoroll (setup.py) ... done
#   Created wheel for pypianoroll: filename=pypianoroll-0.5.3-cp36-none-any.whl size=23827 sha256=bf0c1d40f33ead8e45f1f00190e8ef5692bf57bef761e6279bb9aae5a0185cf4
#   Stored in directory: /root/.cache/pip/wheels/29/c8/c0/7b240ab723c2f96b03391796bdf278de513eabf1dfb989c07f
#   Building wheel for music21 (setup.py) ... done
#   Created wheel for music21: filename=music21-5.7.2-cp36-none-any.whl size=22024602 sha256=d2994891a78001f544d333baa5ccbb4da4c4102ef3dc72899c993bf53929ce54
#   Stored in directory: /root/.cache/pip/wheels/6e/d0/05/1ef3daa9ae295073d807e468fcd820641965086424f1c633e3
#   Building wheel for pretty-midi (setup.py) ... done
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-cp36-none-any.whl size=5591953 sha256=94fd8687acb204826da8e3161450f97b2e92eaf9a334cad30b5e5e5ef50aaff2
#   Stored in directory: /root/.cache/pip/wheels/4c/a1/c6/b5697841db1112c6e5866d75a6b6bf1bef73b874782556ba66
# Successfully built pypianoroll music21 pretty-midi
# Installing collected packages: mido, pretty-midi, pypianoroll, music21, texttable
#   Found existing installation: music21 5.5.0
#     Uninstalling music21-5.5.0:
#       Successfully uninstalled music21-5.5.0
# Successfully installed mido-1.2.9 music21-5.7.2 pretty-midi-0.2.9 pypianoroll-0.5.3 texttable-1.6.2

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import os
import glob
import json
import numpy as np
import keras
from enum import Enum
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, BatchNormalization, Dropout
from keras.optimizers import Adam, RMSprop
from keras import backend as K
from random import randrange
import random
import math
import pypianoroll
from utils.midi_utils import play_midi, plot_pianoroll, get_music_metrics, process_pianoroll, process_midi
from constants import Constants
from augmentation import AddAndRemoveAPercentageOfNotes
from data_generator import PianoRollGenerator
from utils.generate_training_plots import GenerateTrainingPlots
from inference import Inference
from model import OptimizerType
from model import ArCnnModel
# Out:
# Using TensorFlow backend.
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
# !wget http://www-etud.iro.umontreal.ca/~boulanni/JSB%20Chorales.zip
# Out:
# --2020-08-13 04:26:41--  http://www-etud.iro.umontreal.ca/~boulanni/JSB%20Chorales.zip
# Resolving www-etud.iro.umontreal.ca (www-etud.iro.umontreal.ca)... 132.204.26.158
# Connecting to www-etud.iro.umontreal.ca (www-etud.iro.umontreal.ca)|132.204.26.158|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 215242 (210K) [application/zip]
# Saving to: ‘JSB Chorales.zip’
#
# JSB Chorales.zip    100%[===================>] 210.20K   571KB/s    in 0.4s
#
# 2020-08-13 04:26:41 (571 KB/s) - ‘JSB Chorales.zip’ saved [215242/215242]

# %%
# !unzip JSB\ Chorales.zip
# Out:
# Archive:  JSB Chorales.zip
#    creating: JSB Chorales/
#    creating: JSB Chorales/test/
#   inflating: JSB Chorales/test/323.mid
#   inflating: JSB Chorales/test/280.mid
#   inflating: JSB Chorales/test/62.mid
#   inflating: JSB Chorales/test/129.mid
#   inflating: JSB Chorales/test/230.mid
#   inflating: JSB Chorales/test/341.mid
#   inflating: JSB Chorales/test/91.mid
#   inflating: JSB Chorales/test/166.mid
#   inflating: JSB Chorales/test/380.mid
#   inflating: JSB Chorales/test/60.mid
#   inflating: JSB Chorales/test/151.mid
#   inflating: JSB Chorales/test/102.mid
#   inflating: JSB Chorales/test/152.mid
#   inflating: JSB Chorales/test/132.mid
#   inflating: JSB Chorales/test/255.mid
#   inflating: JSB Chorales/test/225.mid
#   inflating: JSB Chorales/test/72.mid
#   inflating: JSB Chorales/test/231.mid
#   inflating: JSB Chorales/test/376.mid
#   inflating: JSB Chorales/test/68.mid
#   inflating: JSB Chorales/test/319.mid
#   inflating: JSB Chorales/test/216.mid
#   inflating: JSB Chorales/test/201.mid
#   inflating: JSB Chorales/test/58.mid
#   inflating: JSB Chorales/test/184.mid
#   inflating: JSB Chorales/test/288.mid
#   inflating: JSB Chorales/test/178.mid
#   inflating: JSB Chorales/test/295.mid
#   inflating: JSB Chorales/test/209.mid
#   inflating: JSB Chorales/test/192.mid
#   inflating: JSB Chorales/test/307.mid
#   inflating: JSB Chorales/test/59.mid
#   inflating: JSB Chorales/test/27.mid
#   inflating: JSB Chorales/test/369.mid
#   inflating: JSB Chorales/test/105.mid
#   inflating: JSB Chorales/test/66.mid
#   inflating: JSB Chorales/test/210.mid
#   inflating: JSB Chorales/test/214.mid
#   inflating: JSB Chorales/test/87.mid
#   inflating: JSB Chorales/test/153.mid
#   inflating: JSB Chorales/test/36.mid
#   inflating: JSB Chorales/test/202.mid
#   inflating: JSB Chorales/test/188.mid
#   inflating: JSB Chorales/test/149.mid
#   inflating: JSB Chorales/test/346.mid
#   inflating: JSB Chorales/test/113.mid
#   inflating: JSB Chorales/test/340.mid
#   inflating: JSB Chorales/test/9.mid
#   inflating: JSB Chorales/test/321.mid
#   inflating: JSB Chorales/test/29.mid
#   inflating: JSB Chorales/test/138.mid
#   inflating: JSB Chorales/test/278.mid
#   inflating: JSB Chorales/test/44.mid
#   inflating: JSB Chorales/test/112.mid
#   inflating: JSB Chorales/test/56.mid
#   inflating: JSB Chorales/test/85.mid
#   inflating: JSB Chorales/test/264.mid
#   inflating: JSB Chorales/test/385.mid
#   inflating: JSB Chorales/test/358.mid
#   inflating: JSB Chorales/test/81.mid
#   inflating: JSB Chorales/test/354.mid
#   inflating: JSB Chorales/test/204.mid
#   inflating: JSB Chorales/test/194.mid
#   inflating: JSB Chorales/test/355.mid
#   inflating: JSB Chorales/test/317.mid
#   inflating: JSB Chorales/test/326.mid
#   inflating: JSB Chorales/test/14.mid
#   inflating: JSB Chorales/test/180.mid
#   inflating: JSB Chorales/test/299.mid
#   inflating: JSB Chorales/test/386.mid
#   inflating: JSB Chorales/test/289.mid
#   inflating: JSB Chorales/test/50.mid
#   inflating: JSB Chorales/test/95.mid
#   inflating: JSB Chorales/test/283.mid
#   inflating: JSB Chorales/test/320.mid
#   inflating: JSB Chorales/test/114.mid
#   inflating: JSB Chorales/test/157.mid
#    creating: JSB Chorales/valid/
#   inflating: JSB Chorales/valid/182.mid
#   inflating: JSB Chorales/valid/208.mid
#   inflating: JSB Chorales/valid/312.mid
#   inflating: JSB Chorales/valid/187.mid
#   inflating: JSB Chorales/valid/107.mid
#   inflating: JSB Chorales/valid/167.mid
#   inflating: JSB Chorales/valid/284.mid
#   inflating: JSB Chorales/valid/324.mid
#   inflating: JSB Chorales/valid/331.mid
#   inflating: JSB Chorales/valid/370.mid
#   inflating: JSB Chorales/valid/189.mid
#   inflating: JSB Chorales/valid/55.mid
#   inflating: JSB Chorales/valid/377.mid
#   inflating: JSB Chorales/valid/374.mid
#   inflating: JSB Chorales/valid/6.mid
#   inflating: JSB Chorales/valid/368.mid
#   inflating: JSB Chorales/valid/243.mid
#   inflating: JSB Chorales/valid/74.mid
#   inflating: JSB Chorales/valid/367.mid
#   inflating: JSB Chorales/valid/256.mid
#   inflating: JSB Chorales/valid/330.mid
#   inflating: JSB Chorales/valid/136.mid
#   inflating: JSB Chorales/valid/221.mid
#   inflating: JSB Chorales/valid/252.mid
#   inflating: JSB Chorales/valid/143.mid
#   inflating: JSB Chorales/valid/101.mid
#   inflating: JSB Chorales/valid/111.mid
#   inflating: JSB Chorales/valid/235.mid
#   inflating: JSB Chorales/valid/115.mid
#   inflating: JSB Chorales/valid/240.mid
#   inflating: JSB Chorales/valid/345.mid
#   inflating: JSB Chorales/valid/371.mid
#   inflating: JSB Chorales/valid/303.mid
#   inflating: JSB Chorales/valid/42.mid
#   inflating: JSB Chorales/valid/94.mid
#   inflating: JSB Chorales/valid/309.mid
#   inflating: JSB Chorales/valid/82.mid
#   inflating: JSB Chorales/valid/30.mid
#   inflating: JSB Chorales/valid/203.mid
#   inflating: JSB Chorales/valid/265.mid
#   inflating: JSB Chorales/valid/389.mid
#   inflating: JSB Chorales/valid/131.mid
#   inflating: JSB Chorales/valid/267.mid
#   inflating: JSB Chorales/valid/329.mid
#   inflating: JSB Chorales/valid/227.mid
#   inflating: JSB Chorales/valid/263.mid
#   inflating: JSB Chorales/valid/43.mid
#   inflating: JSB Chorales/valid/7.mid
#   inflating: JSB Chorales/valid/147.mid
#   inflating: JSB Chorales/valid/170.mid
#   inflating: JSB Chorales/valid/350.mid
#   inflating: JSB Chorales/valid/271.mid
#   inflating: JSB Chorales/valid/25.mid
#   inflating: JSB Chorales/valid/35.mid
#   inflating: JSB Chorales/valid/325.mid
#   inflating: JSB Chorales/valid/20.mid
#   inflating: JSB Chorales/valid/176.mid
#   inflating: JSB Chorales/valid/46.mid
#   inflating: JSB Chorales/valid/181.mid
#   inflating: JSB Chorales/valid/24.mid
#   inflating: JSB Chorales/valid/122.mid
#   inflating: JSB Chorales/valid/211.mid
#   inflating: JSB Chorales/valid/54.mid
#   inflating: JSB Chorales/valid/183.mid
#   inflating: JSB Chorales/valid/120.mid
#   inflating: JSB Chorales/valid/383.mid
#   inflating: JSB Chorales/valid/244.mid
#   inflating: JSB Chorales/valid/348.mid
#   inflating: JSB Chorales/valid/273.mid
#   inflating: JSB Chorales/valid/169.mid
#   inflating: JSB Chorales/valid/1.mid
#   inflating: JSB Chorales/valid/116.mid
#   inflating: JSB Chorales/valid/259.mid
#   inflating: JSB Chorales/valid/155.mid
#   inflating: JSB Chorales/valid/15.mid
#   inflating: JSB Chorales/valid/262.mid
#    creating: JSB Chorales/train/
#   inflating: JSB Chorales/train/219.mid
#   inflating: JSB Chorales/train/69.mid
#   inflating: JSB Chorales/train/172.mid
#   inflating: JSB Chorales/train/134.mid
#   inflating: JSB Chorales/train/275.mid
#   inflating: JSB Chorales/train/26.mid
#   inflating: JSB Chorales/train/245.mid
#   inflating: JSB Chorales/train/327.mid
#   inflating: JSB Chorales/train/301.mid
#   inflating: JSB Chorales/train/274.mid
#   inflating: JSB Chorales/train/212.mid
#   inflating: JSB Chorales/train/37.mid
#   inflating: JSB Chorales/train/379.mid
#   inflating: JSB Chorales/train/52.mid
#   inflating: JSB Chorales/train/246.mid
#   inflating: JSB Chorales/train/207.mid
#   inflating: JSB Chorales/train/356.mid
#   inflating: JSB Chorales/train/228.mid
#   inflating: JSB Chorales/train/17.mid
#   inflating: JSB Chorales/train/296.mid
#   inflating: JSB Chorales/train/88.mid
#   inflating: JSB Chorales/train/238.mid
#   inflating: JSB Chorales/train/337.mid
#   inflating: JSB Chorales/train/164.mid
#   inflating: JSB Chorales/train/366.mid
#   inflating: JSB Chorales/train/302.mid
#   inflating: JSB Chorales/train/61.mid
#   inflating: JSB Chorales/train/378.mid
#   inflating: JSB Chorales/train/343.mid
#   inflating: JSB Chorales/train/162.mid
#   inflating: JSB Chorales/train/239.mid
#   inflating: JSB Chorales/train/248.mid
#   inflating: JSB Chorales/train/173.mid
#   inflating: JSB Chorales/train/11.mid
#   inflating: JSB Chorales/train/384.mid
#   inflating: JSB Chorales/train/33.mid
#   inflating: JSB Chorales/train/80.mid
#   inflating: JSB Chorales/train/98.mid
#   inflating: JSB Chorales/train/125.mid
#   inflating: JSB Chorales/train/328.mid
#   inflating: JSB Chorales/train/254.mid
#   inflating: JSB Chorales/train/67.mid
#   inflating: JSB Chorales/train/272.mid
#   inflating: JSB Chorales/train/352.mid
#   inflating: JSB Chorales/train/249.mid
#   inflating: JSB Chorales/train/5.mid
#   inflating: JSB Chorales/train/135.mid
#   inflating: JSB Chorales/train/318.mid
#   inflating: JSB Chorales/train/158.mid
#   inflating: JSB Chorales/train/351.mid
#   inflating: JSB Chorales/train/177.mid
#   inflating: JSB Chorales/train/154.mid
#   inflating: JSB Chorales/train/124.mid
#   inflating: JSB Chorales/train/357.mid
#   inflating: JSB Chorales/train/71.mid
#   inflating: JSB Chorales/train/226.mid
#   inflating: JSB Chorales/train/84.mid
#   inflating: JSB Chorales/train/372.mid
#   inflating: JSB Chorales/train/333.mid
#   inflating: JSB Chorales/train/362.mid
#   inflating: JSB Chorales/train/39.mid
#   inflating: JSB Chorales/train/79.mid
#   inflating: JSB Chorales/train/49.mid
#   inflating: JSB Chorales/train/108.mid
#   inflating: JSB Chorales/train/347.mid
#   inflating: JSB Chorales/train/382.mid
#   inflating: JSB Chorales/train/258.mid
#   inflating: JSB Chorales/train/338.mid
#   inflating: JSB Chorales/train/16.mid
#   inflating: JSB Chorales/train/93.mid
#   inflating: JSB Chorales/train/257.mid
#   inflating: JSB Chorales/train/2.mid
#   inflating: JSB Chorales/train/292.mid
#   inflating: JSB Chorales/train/150.mid
#   inflating: JSB Chorales/train/332.mid
#   inflating: JSB Chorales/train/234.mid
#   inflating: JSB Chorales/train/229.mid
#   inflating: JSB Chorales/train/311.mid
#   inflating: JSB Chorales/train/174.mid
#   inflating: JSB Chorales/train/190.mid
#   inflating: JSB Chorales/train/146.mid
#   inflating: JSB Chorales/train/261.mid
#   inflating: JSB Chorales/train/141.mid
#   inflating: JSB Chorales/train/253.mid
#   inflating: JSB Chorales/train/119.mid
#   inflating: JSB Chorales/train/360.mid
#   inflating: JSB Chorales/train/285.mid
#   inflating: JSB Chorales/train/293.mid
#   inflating: JSB Chorales/train/220.mid
#   inflating: JSB Chorales/train/270.mid
#   inflating: JSB Chorales/train/196.mid
#   inflating: JSB Chorales/train/106.mid
#   inflating: JSB Chorales/train/361.mid
#   inflating: JSB Chorales/train/205.mid
#   inflating: JSB Chorales/train/127.mid
#   inflating: JSB Chorales/train/250.mid
#   inflating: JSB Chorales/train/179.mid
#   inflating: JSB Chorales/train/314.mid
#   inflating: JSB Chorales/train/110.mid
#   inflating: JSB Chorales/train/200.mid
#   inflating: JSB Chorales/train/51.mid
#   inflating: JSB Chorales/train/279.mid
#   inflating: JSB Chorales/train/373.mid
#   inflating: JSB Chorales/train/21.mid
#   inflating: JSB Chorales/train/13.mid
#   inflating: JSB Chorales/train/233.mid
#   inflating: JSB Chorales/train/76.mid
#   inflating: JSB Chorales/train/123.mid
#   inflating: JSB Chorales/train/300.mid
#   inflating: JSB Chorales/train/99.mid
#   inflating: JSB Chorales/train/83.mid
#   inflating: JSB Chorales/train/215.mid
#   inflating: JSB Chorales/train/100.mid
#   inflating: JSB Chorales/train/142.mid
#   inflating: JSB Chorales/train/8.mid
#   inflating: JSB Chorales/train/222.mid
#   inflating: JSB Chorales/train/73.mid
#   inflating: JSB Chorales/train/364.mid
#   inflating: JSB Chorales/train/298.mid
#   inflating: JSB Chorales/train/148.mid
#   inflating: JSB Chorales/train/381.mid
#   inflating: JSB Chorales/train/97.mid
#   inflating: JSB Chorales/train/165.mid
#   inflating: JSB Chorales/train/75.mid
#   inflating: JSB Chorales/train/185.mid
#   inflating: JSB Chorales/train/342.mid
#   inflating: JSB Chorales/train/277.mid
#   inflating: JSB Chorales/train/103.mid
#   inflating: JSB Chorales/train/109.mid
#   inflating: JSB Chorales/train/38.mid
#   inflating: JSB Chorales/train/126.mid
#   inflating: JSB Chorales/train/304.mid
#   inflating: JSB Chorales/train/334.mid
#   inflating: JSB Chorales/train/349.mid
#   inflating: JSB Chorales/train/294.mid
#   inflating: JSB Chorales/train/23.mid
#   inflating: JSB Chorales/train/64.mid
#   inflating: JSB Chorales/train/57.mid
#   inflating: JSB Chorales/train/19.mid
#   inflating: JSB Chorales/train/290.mid
#   inflating: JSB Chorales/train/305.mid
#   inflating: JSB Chorales/train/247.mid
#   inflating: JSB Chorales/train/28.mid
#   inflating: JSB Chorales/train/90.mid
#   inflating: JSB Chorales/train/339.mid
#   inflating: JSB Chorales/train/310.mid
#   inflating: JSB Chorales/train/365.mid
#   inflating: JSB Chorales/train/45.mid
#   inflating: JSB Chorales/train/32.mid
#   inflating: JSB Chorales/train/53.mid
#   inflating: JSB Chorales/train/198.mid
#   inflating: JSB Chorales/train/313.mid
#   inflating: JSB Chorales/train/315.mid
#   inflating: JSB Chorales/train/286.mid
#   inflating: JSB Chorales/train/12.mid
#   inflating: JSB Chorales/train/86.mid
#   inflating: JSB Chorales/train/217.mid
#   inflating: JSB Chorales/train/168.mid
#   inflating: JSB Chorales/train/89.mid
#   inflating: JSB Chorales/train/92.mid
#   inflating: JSB Chorales/train/63.mid
#   inflating: JSB Chorales/train/96.mid
#   inflating: JSB Chorales/train/104.mid
#   inflating: JSB Chorales/train/197.mid
#   inflating: JSB Chorales/train/291.mid
#   inflating: JSB Chorales/train/163.mid
#   inflating: JSB Chorales/train/195.mid
#   inflating: JSB Chorales/train/140.mid
#   inflating: JSB Chorales/train/47.mid
#   inflating: JSB Chorales/train/260.mid
#   inflating: JSB Chorales/train/4.mid
#   inflating: JSB Chorales/train/266.mid
#   inflating: JSB Chorales/train/193.mid
#   inflating: JSB Chorales/train/40.mid
#   inflating: JSB Chorales/train/161.mid
#   inflating: JSB Chorales/train/353.mid
#   inflating: JSB Chorales/train/316.mid
#   inflating: JSB Chorales/train/236.mid
#   inflating: JSB Chorales/train/171.mid
#   inflating: JSB Chorales/train/156.mid
#   inflating: JSB Chorales/train/281.mid
#   inflating: JSB Chorales/train/241.mid
#   inflating: JSB Chorales/train/359.mid
#   inflating: JSB Chorales/train/335.mid
#   inflating: JSB Chorales/train/137.mid
#   inflating: JSB Chorales/train/144.mid
#   inflating: JSB Chorales/train/128.mid
#   inflating: JSB Chorales/train/22.mid
#   inflating: JSB Chorales/train/159.mid
#   inflating: JSB Chorales/train/287.mid
#   inflating: JSB Chorales/train/344.mid
#   inflating: JSB Chorales/train/375.mid
#   inflating: JSB Chorales/train/48.mid
#   inflating: JSB Chorales/train/206.mid
#   inflating: JSB Chorales/train/237.mid
#   inflating: JSB Chorales/train/18.mid
#   inflating: JSB Chorales/train/3.mid
#   inflating: JSB Chorales/train/160.mid
#   inflating: JSB Chorales/train/363.mid
#   inflating: JSB Chorales/train/276.mid
#   inflating: JSB Chorales/train/306.mid
#   inflating: JSB Chorales/train/117.mid
#   inflating: JSB Chorales/train/322.mid
#   inflating: JSB Chorales/train/282.mid
#   inflating: JSB Chorales/train/186.mid
#   inflating: JSB Chorales/train/251.mid
#   inflating: JSB Chorales/train/242.mid
#   inflating: JSB Chorales/train/118.mid
#   inflating: JSB Chorales/train/308.mid
#   inflating: JSB Chorales/train/145.mid
#   inflating: JSB Chorales/train/224.mid
#   inflating: JSB Chorales/train/268.mid
#   inflating: JSB Chorales/train/70.mid
#   inflating: JSB Chorales/train/65.mid
#   inflating: JSB Chorales/train/130.mid
#   inflating: JSB Chorales/train/232.mid
#   inflating: JSB Chorales/train/34.mid
#   inflating: JSB Chorales/train/175.mid
#   inflating: JSB Chorales/train/78.mid
#   inflating: JSB Chorales/train/31.mid
#   inflating: JSB Chorales/train/387.mid
#   inflating: JSB Chorales/train/388.mid
#   inflating: JSB Chorales/train/77.mid
#   inflating: JSB Chorales/train/269.mid
#   inflating: JSB Chorales/train/10.mid
#   inflating: JSB Chorales/train/41.mid
#   inflating: JSB Chorales/train/223.mid
#   inflating: JSB Chorales/train/139.mid
#   inflating: JSB Chorales/train/218.mid

# %%
data_dir = 'JSB Chorales/**/*.mid'
midi_files = glob.glob(data_dir)

random_midi = randrange(len(midi_files))
play_midi(midi_files[random_midi])
# Out:
#                 <div id='midiPlayerDiv1254'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv1254');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
def generate_samples(midi_files, bars, beats_per_bar, beat_resolution, bars_shifted_per_sample):
    """
    dataset_files: All files in the dataset
    return: piano roll samples sized to X bars
    """
    timesteps_per_nbars = bars * beats_per_bar * beat_resolution
    time_steps_shifted_per_sample = bars_shifted_per_sample * beats_per_bar * beat_resolution
    samples = []
    for midi_file in midi_files:
        pianoroll = process_midi(midi_file, beat_resolution) 
        samples.extend(process_pianoroll(pianoroll, time_steps_shifted_per_sample, timesteps_per_nbars))
    return samples

# %%
dataset_samples = generate_samples(midi_files, Constants.bars, Constants.beats_per_bar,Constants.beat_resolution, Constants.bars_shifted_per_sample)

random.shuffle(dataset_samples);

# %%
random_pianoroll = dataset_samples[randrange(len(dataset_samples))]
plot_pianoroll(pianoroll = random_pianoroll,
               beat_resolution = 4)

# %%
sampling_lower_bound_remove = 0 
sampling_upper_bound_remove = 100
sampling_lower_bound_add = 1
sampling_upper_bound_add = 1.5

# %%
class Loss():
    @staticmethod 
    def built_in_softmax_kl_loss(target, output):
        '''
        Custom Loss Function
        :param target: ground truth values
        :param output: predicted values
        :return kullback_leibler_divergence loss
        '''
        target = K.flatten(target)
        output = K.flatten(output)
        target = target / K.sum(target)
        output = K.softmax(output)
        return keras.losses.kullback_leibler_divergence(target, output)

# %%
dataset_size = len(dataset_samples)
dataset_split = math.floor(dataset_size * Constants.training_validation_split) 

training_samples = dataset_samples[0:dataset_split]
print("training samples length: {}".format(len(training_samples)))
validation_samples = dataset_samples[dataset_split + 1:dataset_size]
print("validation samples length: {}".format(len(validation_samples)))
# Out:
# training samples length: 881
# validation samples length: 97

# %%
input_dim = (Constants.bars * Constants.beats_per_bar * Constants.beat_resolution, 
             Constants.number_of_pitches, 
             Constants.number_of_channels)
num_filters = 32
growth_factor = 2
num_layers = 5
dropout_rate_encoder = [0, 0.5, 0.5, 0.5, 0.5]
dropout_rate_decoder = [0.5, 0.5, 0.5, 0.5, 0]
batch_norm_encoder = [True, True, True, True, False]
batch_norm_decoder = [True, True, True, True, False]
pre_trained = False
learning_rate = 0.001
optimizer_enum = OptimizerType.ADAM
batch_size = 128
epochs =  200

# %%
steps_per_epoch = int(
    len(training_samples) * Constants.samples_per_ground_truth_data_item / int(batch_size))

print("The Total Number Of Steps Per Epoch Are: "+ str(steps_per_epoch))

n_timesteps = Constants.bars * Constants.beat_resolution * Constants.beats_per_bar
# Out:
# The Total Number Of Steps Per Epoch Are: 55

# %%
training_data_generator = PianoRollGenerator(sample_list=training_samples,
                                             sampling_lower_bound_remove = sampling_lower_bound_remove,
                                             sampling_upper_bound_remove = sampling_upper_bound_remove,
                                             sampling_lower_bound_add = sampling_lower_bound_add,
                                             sampling_upper_bound_add = sampling_upper_bound_add,
                                             batch_size = batch_size,
                                             bars = Constants.bars,
                                             samples_per_data_item = Constants.samples_per_ground_truth_data_item,
                                             beat_resolution = Constants.beat_resolution,
                                             beats_per_bar = Constants.beats_per_bar,
                                             number_of_pitches = Constants.number_of_pitches,
                                             number_of_channels = Constants.number_of_channels)

# %%
validation_data_generator = PianoRollGenerator(sample_list = validation_samples,
                                               sampling_lower_bound_remove = sampling_lower_bound_remove,
                                               sampling_upper_bound_remove = sampling_upper_bound_remove,
                                               sampling_lower_bound_add = sampling_lower_bound_add,
                                               sampling_upper_bound_add = sampling_upper_bound_add,
                                               batch_size = batch_size, 
                                               bars = Constants.bars,
                                               samples_per_data_item = Constants.samples_per_ground_truth_data_item,
                                               beat_resolution = Constants.beat_resolution,
                                               beats_per_bar = Constants.beats_per_bar, 
                                               number_of_pitches = Constants.number_of_pitches,
                                               number_of_channels = Constants.number_of_channels)

# %%
plot_losses = GenerateTrainingPlots()
checkpoint_filepath =  'checkpoints/-best-model-epoch:{epoch:04d}.hdf5'

model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

callbacks_list = [plot_losses, model_checkpoint_callback]

# %%
MusicModel = ArCnnModel(input_dim = input_dim,
                        num_filters = num_filters,
                        growth_factor = growth_factor,
                        num_layers = num_layers,
                        dropout_rate_encoder = dropout_rate_encoder,
                        dropout_rate_decoder = dropout_rate_decoder,
                        batch_norm_encoder = batch_norm_encoder,
                        batch_norm_decoder = batch_norm_decoder,
                        pre_trained = pre_trained,
                        learning_rate = learning_rate,
                        optimizer_enum = optimizer_enum)

# %%
model = MusicModel.build_model()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 32)   128         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   18496       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 64)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  73856       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 128)  0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  295168      batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 256)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 256)    0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 256)    1024        dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    1180160     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 512)    2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 4, 4, 512)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 4, 4, 512)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 1024)   4719616     dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 1024)   9438208     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 1024)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 1536)   0           up_sampling2d_1[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 1536)   6144        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 512)    7078400     batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 512)    2359808     conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 8, 8, 512)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 512)  0           dropout_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 768)  0           up_sampling2d_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 768)  3072        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 256)  1769728     batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 16, 16, 256)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 256)  0           dropout_10[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 384)  0           up_sampling2d_3[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 384)  1536        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 128)  442496      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 32, 128)  0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 128)  0           dropout_11[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 192)  0           up_sampling2d_4[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 192)  768         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 64)   110656      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64, 64, 64)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 64) 0           dropout_12[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128, 128, 96) 0           up_sampling2d_5[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 32) 27680       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 1)  33          conv2d_22[0][0]
# ==================================================================================================
# Total params: 31,455,553
# Trainable params: 31,448,833
# Non-trainable params: 6,720
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(training_data_generator,
                              validation_data = validation_data_generator,
                              steps_per_epoch = steps_per_epoch,
                              epochs = epochs,
                              callbacks = callbacks_list)

# %%
checkpoints = !ls -t checkpoints | head -n1
print(checkpoints)
# Out:
# ['-best-model-epoch:0186.hdf5']
